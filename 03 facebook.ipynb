# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('dataset_Facebook.csv', sep=';')
df
# Out:
#      Page total likes    Type  Category  Post Month  Post Weekday  Post Hour  \
# 0              139441   Photo         2          12             4          3
# 1              139441  Status         2          12             3         10
# 2              139441   Photo         3          12             3          3
# 3              139441   Photo         2          12             2         10
# 4              139441   Photo         2          12             2          3
# ..                ...     ...       ...         ...           ...        ...
# 495             85093   Photo         3           1             7          2
# 496             81370   Photo         2           1             5          8
# 497             81370   Photo         1           1             5          2
# 498             81370   Photo         3           1             4         11
# 499             81370   Photo         2           1             4          4
#
# ...

# %%
# Perform the following operations using Python on the Facebook metrics data sets
# a. Create data subsets
# b. Merge Data
# c. Sort Data
# d. Transposing Data
# e. Shape and reshape Data

# %%
# a. Create data subsets

# %%
subset1 = df[['like', 'share']]
subset1
# Out:
#        like  share
# 0      79.0   17.0
# 1     130.0   29.0
# 2      66.0   14.0
# 3    1572.0  147.0
# 4     325.0   49.0
# ..      ...    ...
# 495    53.0   26.0
# 496    53.0   22.0
# 497    93.0   18.0
# 498    91.0   38.0
# 499    91.0   28.0
#
# [500 rows x 2 columns]

# %%
subset2 = df[df['like']>500]
subset2
# Out:
#      Page total likes    Type  Category  Post Month  Post Weekday  Post Hour  \
# 3              139441   Photo         2          12             2         10
# 14             138414   Photo         2          12             4          5
# 17             138414   Photo         1          12             2         12
# 28             138895   Photo         2          12             5          3
# 67             138185   Photo         1          11             7          3
# 101            137020   Photo         2          10             4          3
# 105            137020   Photo         1          10             2          4
# 142            136013  Status         2          10             3          2
# 168            135428   Photo         1           9             3         10
# 176            135195   Photo         3           9             6          3
# 191            133679   Photo         3           8             1         10
# ...

# %%
# subset3 = df.iloc[0:5]
subset3 = df.loc[[0,1,2,3,4,5], ['like', 'share']]
subset3
# Out:
#      like  share
# 0    79.0   17.0
# 1   130.0   29.0
# 2    66.0   14.0
# 3  1572.0  147.0
# 4   325.0   49.0
# 5   152.0   33.0

# %%
# b. Merge Data

# %%
merge1 = df.iloc[0:250]
merge2 = df.iloc[250:]
# Out:
#      Page total likes    Type  Category  Post Month  Post Weekday  Post Hour  \
# 0              139441   Photo         2          12             4          3
# 1              139441  Status         2          12             3         10
# 2              139441   Photo         3          12             3          3
# 3              139441   Photo         2          12             2         10
# 4              139441   Photo         2          12             2          3
# ..                ...     ...       ...         ...           ...        ...
# 245            130791   Photo         1           7             2         13
# 246            130791   Photo         2           7             2          8
# 247            129600   Photo         2           7             1         12
# 248            129600   Photo         3           7             1          6
# 249            129600   Photo         2           7             7         11
#
# ...

# %%
merge_final = pd.concat([merge1,merge2])
merge_final
# Out:
#      Page total likes    Type  Category  Post Month  Post Weekday  Post Hour  \
# 0              139441   Photo         2          12             4          3
# 1              139441  Status         2          12             3         10
# 2              139441   Photo         3          12             3          3
# 3              139441   Photo         2          12             2         10
# 4              139441   Photo         2          12             2          3
# ..                ...     ...       ...         ...           ...        ...
# 495             85093   Photo         3           1             7          2
# 496             81370   Photo         2           1             5          8
# 497             81370   Photo         1           1             5          2
# 498             81370   Photo         3           1             4         11
# 499             81370   Photo         2           1             4          4
#
# ...

# %%
# c. Sort Data

# %%
sortlike = df.sort_values('like')
sortlike
# Out:
#      Page total likes   Type  Category  Post Month  Post Weekday  Post Hour  \
# 21             138414  Photo         1          12             7         10
# 417            104070  Photo         1           3             3         10
# 100            137020  Photo         1          10             4          9
# 76             137893  Photo         1          11             3          2
# 441             98195  Photo         1           3             5          4
# ..                ...    ...       ...         ...           ...        ...
# 168            135428  Photo         1           9             3         10
# 349            117764  Photo         3           5             5         13
# 379            111620  Photo         3           4             1         14
# 244            130791  Photo         2           7             3          5
# 111            136736  Photo         1          10             6          8
#
# ...

# %%
sorttotal = df.sort_values('Page total likes')
sorttotal
# Out:
#      Page total likes    Type  Category  Post Month  Post Weekday  Post Hour  \
# 499             81370   Photo         2           1             4          4
# 496             81370   Photo         2           1             5          8
# 498             81370   Photo         3           1             4         11
# 497             81370   Photo         1           1             5          2
# 493             85093   Photo         3           1             1          2
# ..                ...     ...       ...         ...           ...        ...
# 10             139441  Status         2          12             5         10
# 11             139441   Photo         2          12             5         10
# 13             139441   Photo         2          12             5          3
# 7              139441   Photo         3          12             7          9
# 0              139441   Photo         2          12             4          3
#
# ...

# %%
sortcomment = df.sort_values('comment', ascending=False)
sortcomment
# Out:
#      Page total likes   Type  Category  Post Month  Post Weekday  Post Hour  \
# 244            130791  Photo         2           7             3          5
# 460             92507  Photo         3           2             1         13
# 168            135428  Photo         1           9             3         10
# 288            126141  Photo         1           6             4         12
# 228            131728  Photo         2           7             4          3
# ..                ...    ...       ...         ...           ...        ...
# 332            119198  Photo         3           5             2         12
# 333            119198  Photo         3           5             2          1
# 111            136736  Photo         1          10             6          8
# 103            137020  Photo         1          10             3          4
# 499             81370  Photo         2           1             4          4
#
# ...

# %%
# d. Transposing Data

# %%
transpose = df.transpose()
transpose
# Out:
#                                                        0       1       2    \
# Page total likes                                    139441  139441  139441
# Type                                                 Photo  Status   Photo
# Category                                                 2       2       3
# Post Month                                              12      12      12
# Post Weekday                                             4       3       3
# Post Hour                                                3      10       3
# Paid                                                   0.0     0.0     0.0
# Lifetime Post Total Reach                             2752   10460    2413
# Lifetime Post Total Impressions                       5091   19057    4373
# Lifetime Engaged Users                                 178    1457     177
# Lifetime Post Consumers                                109    1361     113
# ...

# %%
# e. Shape and reshape Data

# %%
test1 = df.iloc[[1,2,3,4,5], [15,16,17]]
test1
# Out:
#    comment    like  share
# 1        5   130.0   29.0
# 2        0    66.0   14.0
# 3       58  1572.0  147.0
# 4       19   325.0   49.0
# 5        1   152.0   33.0

# %%
test2 = test1.melt(id_vars='comment', value_vars=['like', 'share'])
test2
# Out:
#    comment variable   value
# 0        5     like   130.0
# 1        0     like    66.0
# 2       58     like  1572.0
# 3       19     like   325.0
# 4        1     like   152.0
# 5        5    share    29.0
# 6        0    share    14.0
# 7       58    share   147.0
# 8       19    share    49.0
# 9        1    share    33.0

# %%
test3 = test2.pivot(index='comment', columns='variable', values='value')
test3
# Out:
# variable    like  share
# comment
# 0           66.0   14.0
# 1          152.0   33.0
# 5          130.0   29.0
# 19         325.0   49.0
# 58        1572.0  147.0
